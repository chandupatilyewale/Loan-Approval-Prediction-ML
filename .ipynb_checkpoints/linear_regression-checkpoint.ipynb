# %%
import numpy as np

# %%
def LinearRegression():
    def _init_(self, learning_rate, n_iter):
        self.bais = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

        m,n = x.shape
        def fit():
            self.bias = 0
            self.weights = np.zeros(n)
